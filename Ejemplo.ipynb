# %%
import sys
import os
from matplotlib import pyplot as plt
src=f"{os.getcwd()}/src"
if src not in sys.path:
    sys.path.append(src)
from SimpleEC import *
from operators import *

# %%
ecb=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='b',
             parents_selection=proportional_selection, population_size=150)
ecg=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='g',population_size=150)

# %%
avgb,bestb=ecb.evolve()
avgg,bestg=ecg.evolve()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(bestb, label='Best Binary')
ax.plot(bestg, label='Best Gray')
ax.legend()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(avgb, label='Avg Binary')
ax.plot(avgg, label='Avg Gray')
ax.legend()

# %%
ecf=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='f',
             crossover=undx,np=3,population_size=150)

# %%
avgf,bestf=ecf.evolve()
# Out:
# /Users/job/baile/src/operators.py:28: RuntimeWarning: invalid value encountered in divide
#   e=d/dn

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(avgb, label='Avg Binary')
ax.plot(avgg, label='Avg Gray')
ax.plot(avgf, label='Avg Float')
ax.legend()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(bestb, label='Best Binary')
ax.plot(bestg, label='Best Gray')
ax.plot(bestf, label='Best Float')
ax.legend()

# %%
ecg.fit*ecb.opt
# Out:
# array([-919.5899869 , -919.5899869 , -900.03751111, -900.03751111,
#        -897.47291745, -897.47291745, -897.47291745, -897.47291745,
#        -887.13294622, -887.13294622, -887.13294622, -887.13294622,
#        -887.13294622, -887.13294622, -884.33693124, -884.33693124,
#        -884.33693124, -884.33693124, -884.33693124, -880.35096577,
#        -880.35096577, -880.35096577, -880.35096577, -880.35096577,
#        -872.14141406, -872.14141406, -872.14141406, -872.14141406,
#        -872.14141406, -872.14141406, -872.14141406, -872.14141406,
#        -872.14141406, -872.14141406, -872.14141406, -872.14141406,
#        -872.14141406, -872.14141406, -872.14141406, -872.14141406,
#        -869.11954291, -869.11954291, -855.0729603 , -832.49055141,
#        -832.49055141, -832.49055141, -832.49055141, -832.49055141,
#        -832.49055141, -832.49055141, -829.67360374, -829.67360374,
#        -825.62365825, -825.62365825, -825.62365825, -825.62365825,
#        -823.49508292, -823.49508292, -814.79374367, -814.79374367,
#        -814.79374367, -814.79374367, -814.79374367, -814.79374367,
#        -814.79374367, -814.79374367, -803.31345994, -803.31345994,
#        -803.31345994, -803.31345994, -803.31345994, -803.31345994,
#        -803.31345994, -803.31345994, -803.31345994, -803.31345994,
#        -803.31345994, -803.31345994, -803.31345994, -803.31345994,
#        -803.31345994, -803.31345994, -803.31345994, -797.8745068 ,
#        -795.1425983 , -795.1425983 , -791.65299813, -791.65299813,
#        -791.65299813, -791.65299813, -782.97295334, -782.97295334,
#        -781.20333143, -779.04608812, -762.51049573, -758.7997514 ,
#        -758.7997514 , -758.7997514 , -758.7997514 , -758.07082392,
#        -758.07082392, -757.21549111, -757.21549111, -739.62739795,
#        -735.36965109, -734.65808318, -732.80891253, -731.41370459,
#        -731.41370459, -731.41370459, -731.41370459, -731.41370459,
#        -731.41370459, -724.90604099, -724.90604099, -724.90604099,
#        -724.90604099, -710.88132463, -710.88132463, -706.43735602,
#        -706.43735602, -703.87537499, -703.87537499, -703.87537499,
#        -703.87537499, -703.87537499, -703.87537499, -703.87537499,
#        -703.87537499, -680.42654589, -680.42654589, -648.36464122,
#        -648.36464122, -639.22158357, -639.22158357, -639.22158357,
#        -639.22158357, -639.22158357, -639.22158357, -631.01673183,
#        -605.53506699, -605.53506699, -596.78997935, -596.78997935,
#        -596.78997935, -596.78997935, -596.78997935, -540.96231721,
#        -506.09525941, -497.65161219])
