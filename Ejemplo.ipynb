# %%
import sys
import os
from matplotlib import pyplot as plt
src=f"{os.getcwd()}/src"
if src not in sys.path:
    sys.path.append(src)
from SimpleEC import *
from operators import *

# %%
ecb=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='b',
             parents_selection=proportional_selection, population_size=100)
ecg=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='g',population_size=100)

# %%
avgb,bestb=ecb.evolve()
avgg,bestg=ecg.evolve()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(bestb, label='Best Binary')
ax.plot(bestg, label='Best Gray')
ax.legend()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(avgb, label='Avg Binary')
ax.plot(avgg, label='Avg Gray')
ax.legend()

# %%
ecf=SimpleEC(eggholder,[(-512,512),(-512,512)], coding='f',
             crossover=undx,np=3,population_size=100)

# %%
avgf,bestf=ecf.evolve()
# Out:
# /Users/job/baile/src/operators.py:28: RuntimeWarning: invalid value encountered in divide
#   e=d/dn

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(avgb, label='Avg Binary')
ax.plot(avgg, label='Avg Gray')
ax.plot(avgf, label='Avg Float')
ax.legend()

# %%
fig,ax=plt.subplots(1,1,figsize=(3,3))
ax.plot(bestb, label='Best Binary')
ax.plot(bestg, label='Best Gray')
ax.plot(bestf, label='Best Float')
ax.legend()

# %%
ecg.fit*ecb.opt
# Out:
# array([-931.6163292 , -930.85165893, -930.85165893, -930.85165893,
#        -930.85165893, -930.85165893, -930.85165893, -930.85165893,
#        -928.20748951, -928.20748951, -928.20748951, -928.20748951,
#        -928.20748951, -928.20748951, -928.20748951, -926.89082443,
#        -926.89082443, -926.89082443, -926.89082443, -926.89082443,
#        -926.89082443, -926.89082443, -926.89082443, -926.89082443,
#        -926.89082443, -926.89082443, -926.89082443, -926.89082443,
#        -926.89082443, -926.89082443, -926.89082443, -925.19312658,
#        -925.19312658, -924.95727692, -924.95727692, -924.95727692,
#        -924.95727692, -924.95727692, -924.95727692, -924.95727692,
#        -924.95727692, -924.42264788, -923.21607519, -922.69322181,
#        -922.69322181, -922.36770331, -922.19357124, -922.19357124,
#        -922.19357124, -922.19357124, -922.19357124, -922.19357124,
#        -922.19357124, -922.19357124, -919.57470879, -919.57470879,
#        -919.57470879, -919.57470879, -919.57470879, -919.57470879,
#        -919.57470879, -919.57470879, -919.57470879, -919.26572898,
#        -919.26572898, -919.26572898, -919.26572898, -919.26572898,
#        -916.56770446, -916.56770446, -916.56770446, -916.56770446,
#        -916.56770446, -916.56770446, -916.25337401, -916.25337401,
#        -915.02909708, -915.02909708, -915.02909708, -915.02909708,
#        -915.02909708, -915.02909708, -915.02909708, -915.02909708,
#        -913.39120539, -909.27917487, -909.27917487, -909.27917487,
#        -907.00360824, -905.51963315, -905.51963315, -905.51963315,
#        -905.51963315, -905.51963315, -905.51963315, -902.70647866,
#        -902.38507845, -902.38507845, -895.2718823 , -895.2718823 ,
#        -895.2718823 , -894.5209769 , -894.5209769 , -894.5209769 ,
#        -894.5209769 , -891.18364676, -891.18364676, -878.88314502,
#        -878.88314502, -878.88314502, -878.88314502, -878.88314502,
#        -878.88314502, -878.88314502, -878.88314502, -866.77545021,
#        -865.48001376, -865.48001376, -862.48414817, -860.82455027,
#        -844.20229278, -844.20229278, -844.20229278, -841.70970574,
#        -841.70970574, -841.70970574, -830.41967361, -830.41967361,
#        -830.20594552, -830.20594552, -830.20594552, -828.71389263,
#        -828.71389263, -809.17310873, -807.99953891, -807.99953891,
#        -807.99953891, -807.99953891, -785.94529649, -785.34470478,
#        -760.80064409, -760.80064409, -759.99507627, -734.43166638,
#        -734.43166638, -734.43166638, -734.43166638, -734.43166638,
#        -734.43166638, -734.43166638, -733.81513958, -733.81513958,
#        -733.81513958, -733.81513958, -727.46077402, -726.49342486,
#        -726.49342486, -725.74412756, -720.38385094, -720.38385094,
#        -706.31580597, -706.31580597, -706.31580597, -706.31580597,
#        -705.89173306, -705.89173306, -705.89173306, -705.89173306,
#        -705.89173306, -701.62480691, -696.44747698, -696.44747698,
#        -691.89535348, -676.31703216, -675.69909952, -674.69219634,
#        -670.81124227, -670.81124227, -670.81124227, -670.81124227,
#        -670.81124227, -642.77443364, -642.77443364, -642.77443364,
#        -641.19091774, -639.28576217, -639.28576217, -609.45610707,
#        -578.8354122 , -574.88346653, -540.96231721, -471.97143867,
#        -360.99287918, -316.08995313, -316.08995313, -313.31362791,
#        -313.31362791, -313.31362791, -242.27987069, -242.27987069])
